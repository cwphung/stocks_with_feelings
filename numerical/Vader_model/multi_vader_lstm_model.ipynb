# %% [markdown]
# # Multi-task LSTM Model with Sentiment Analysis
#
# This notebook trains a regression+classification LSTM model using price and sentiment data from multiple stocks.

# %%
import sys
import warnings

if not sys.warnoptions:
    warnings.simplefilter('ignore')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report

from numerical_preprocessing import *

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

tf.random.set_seed(1234)

# %% [markdown]
# Check if GPU is available

# %%
print("TensorFlow Version:", tf.__version__)
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
# Out:
# TensorFlow Version: 2.16.2
# Num GPUs Available: 1

# %%
tf.config.experimental.set_memory_growth(tf.config.list_physical_devices('GPU')[0], True)

# %% [markdown]
# ### Import Dataset

# %%
stocks = pd.read_csv("../stock_yfinance_data.csv")
stocks.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2021-09-30  260.333344  263.043335  258.333344  258.493347  258.493347
# 1  2021-10-01  259.466675  260.260010  254.529999  258.406677  258.406677
# 2  2021-10-04  265.500000  268.989990  258.706665  260.510010  260.510010
# 3  2021-10-05  261.600006  265.769989  258.066681  260.196655  260.196655
# 4  2021-10-06  258.733337  262.220001  257.739990  260.916656  260.916656
#
#      Volume Stock Name
# 0  53868000       TSLA
# 1  51094200       TSLA
# 2  91449900       TSLA
# 3  55297800       TSLA
# 4  43898400       TSLA

# %%
tweets = pd.read_csv("../stock_tweets.csv")
tweets.head()
# Out:
#                         Date  \
# 0  2022-09-29 23:41:16+00:00
# 1  2022-09-29 23:24:43+00:00
# 2  2022-09-29 23:18:08+00:00
# 3  2022-09-29 22:40:07+00:00
# 4  2022-09-29 22:27:05+00:00
#
#                                                Tweet Stock Name Company Name
# 0  Mainstream media has done an amazing job at br...       TSLA  Tesla, Inc.
# 1  Tesla delivery estimates are at around 364k fr...       TSLA  Tesla, Inc.
# 2  3/ Even if I include 63.0M unvested RSUs as of...       TSLA  Tesla, Inc.
# 3  @RealDanODowd @WholeMarsBlog @Tesla Hahaha why...       TSLA  Tesla, Inc.
# 4  @RealDanODowd @Tesla Stop trying to kill kids,...       TSLA  Tesla, Inc.

# %%
sentiment = calculate_mean_sentiment(tweets)
sentiment.head()
# Out:
# Calculating Sentiment Scores: 100%|██████████| 80793/80793 [12:43<00:00, 105.84it/s]
#          Date Stock Name  Sentiment
# 0  2021-09-30       AAPL    0.09890
# 1  2021-09-30        AMD    0.41780
# 2  2021-09-30       AMZN    0.24648
# 3  2021-09-30        DIS    0.54610
# 4  2021-09-30       GOOG    0.44040

# %%
sentiment['Date'] = sentiment['Date'].astype(str)
data = pd.merge(stocks, sentiment, on=['Date', 'Stock Name'], how="left")
data['Sentiment'] = data['Sentiment'].fillna(0)
data.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2021-09-30  260.333344  263.043335  258.333344  258.493347  258.493347
# 1  2021-10-01  259.466675  260.260010  254.529999  258.406677  258.406677
# 2  2021-10-04  265.500000  268.989990  258.706665  260.510010  260.510010
# 3  2021-10-05  261.600006  265.769989  258.066681  260.196655  260.196655
# 4  2021-10-06  258.733337  262.220001  257.739990  260.916656  260.916656
#
#      Volume Stock Name  Sentiment
# 0  53868000       TSLA   0.231552
# 1  51094200       TSLA   0.233704
# 2  91449900       TSLA   0.135388
# 3  55297800       TSLA   0.069445
# 4  43898400       TSLA   0.199940

# %%
data.to_csv("stock_sentiment.csv", index=False)

# %% [markdown]
# ### Preprocess Stocks

# %%
feature_cols = ['percent_open', 'percent_high', 'percent_low', 'percent_close', 'volume', 
                'sma', 'ema', 'rsi', 'macd', 'sentiment']
target_cols = ['future_magnitude', 'future_direction']
num_features = len(feature_cols)
num_targets = len(target_cols)
prev_days = 20
future_days = 1
test_size = 30 # days per stock

# %%
train_x = []
train_y = []
test_x = []
test_y = []

train_tickers = []
test_tickers = []
scalers = {}

train_data = pd.DataFrame({})
test_data = pd.DataFrame({})

tickers = data['Stock Name'].unique()

for ticker in tickers:

    # Filter for stock data
    stock_data = data[data['Stock Name'] == ticker]

    # Clean data
    stock_data = clean_stock_data(stock_data, ticker=None)

    # Calculate percent change between trading days
    stock_data['percent_open'], stock_data['percent_high'], stock_data['percent_low'], stock_data['percent_close'] = percent_price_change(stock_data)
    
    # Calculate technical indicators
    stock_data['sma'] = simple_moving_average(stock_data)
    stock_data['ema'] = exponential_moving_average(stock_data)
    stock_data['rsi'] = calculate_rsi(stock_data)
    stock_data['macd_line'], stock_data['macd_signal'], stock_data['macd'] = calculate_macd(stock_data)
    stock_data['bb_middle'], stock_data['bb_upper'], stock_data['bb_lower'] = bollinger_bands(stock_data)
    stock_data['future_percent'] = calculate_future_close(stock_data)
    stock_data.dropna(inplace=True)

    # Compute regression & binary classification targets before scaling
    stock_data['future_magnitude'] = stock_data['future_percent'].abs() # convert to magnitude
    stock_data['future_direction'] = (stock_data['future_percent'] > 0).astype(int)  # 1 if up, 0 if down

    # Normalize features
    scaler = MinMaxScaler()
    scale_cols = feature_cols+[target_cols[0]]
    stock_data.loc[:, scale_cols] = scaler.fit_transform(stock_data.loc[:, scale_cols])
    scalers[ticker] = scaler

    # Generate training & test feature data
    feature_array = stock_data[feature_cols].to_numpy()
    stock_x = generate_feature_data(feature_array, sequence_size=prev_days, pred_size=future_days)

    # Slice stock_data properly to match sequence data
    stock_data = stock_data.iloc[prev_days:-future_days].reset_index(drop=True)

    # Stack y1-magnitude (regression) and y2-direction (classification)
    stock_y1 = stock_data['future_magnitude'].to_numpy()
    stock_y2 = stock_data['future_direction'].to_numpy()
    train_y.append(np.column_stack((stock_y1[:-test_size], stock_y2[:-test_size])))
    test_y.append(np.column_stack((stock_y1[-test_size:], stock_y2[-test_size:])))

    # Append data
    train_x.append(stock_x[:-test_size])
    test_x.append(stock_x[-test_size:])

    # Track stock names for each entry
    train_tickers.extend([ticker] * (len(stock_x) - test_size))
    test_tickers.extend([ticker] * test_size)

    # Append clean stock data
    train_data = pd.concat([train_data, stock_data.iloc[:-test_size]], ignore_index=True)
    test_data = pd.concat([test_data, stock_data.iloc[-test_size:]], ignore_index=True)

# Convert training and testing sets to arrays
train_x = np.vstack(train_x)
train_y = np.vstack(train_y)
test_x = np.vstack(test_x)
test_y = np.vstack(test_y)

# Convert stock labels to arrays
train_tickers = np.array(train_tickers)
test_tickers = np.array(test_tickers)

# %%
train_data
# Out:
#             date        open        high         low       close   adj_close  \
# 0     2021-11-24  360.130005  377.589996  354.000000  372.000000  372.000000
# 1     2021-11-26  366.489990  369.593323  360.333344  360.640015  360.640015
# 2     2021-11-29  366.996674  380.890015  366.730011  378.996674  378.996674
# 3     2021-11-30  381.456665  389.333344  372.666656  381.586670  381.586670
# 4     2021-12-01  386.899994  390.946655  363.586670  365.000000  365.000000
# ...          ...         ...         ...         ...         ...         ...
# 4520  2022-08-09   23.320000   23.709999   22.139999   22.690001   22.690001
# 4521  2022-08-10   23.110001   23.110001   22.040001   22.900000   22.900000
# 4522  2022-08-11   23.580000   25.910000   23.209999   24.610001   24.610001
# 4523  2022-08-12   23.670000   24.480000   23.379999   24.410000   24.410000
# 4524  2022-08-15   23.424999   23.610001   22.639999   23.500000   23.500000
#
#         volume stock_name  sentiment  percent_open  ...       rsi  macd_line  \
# 0     0.229401       TSLA   0.795333      0.313920  ...  0.284683  14.595007
# 1     0.000000       TSLA   0.385339      0.374061  ...  0.261214  13.006359
# 2     0.164125       TSLA   0.596957      0.551208  ...  0.392891  13.077820
# 3     0.324958       TSLA   0.450048      0.490397  ...  0.611356  13.191382
# 4     0.234811       TSLA   0.559798      0.530992  ...  0.464531  11.806873
# ...        ...        ...        ...           ...  ...       ...        ...
# 4520  0.157525       XPEV   0.433110      0.408956  ...  0.215070  -1.467863
# 4521  0.147302       XPEV   0.433110      0.430488  ...  0.223351  -1.464131
# 4522  0.404596       XPEV   0.433110      0.463771  ...  0.558296  -1.308111
# 4523  0.096472       XPEV   0.433110      0.261734  ...  0.578805  -1.186920
# 4524  0.268311       XPEV   0.433110      0.255316  ...  0.509445  -1.151037
#
#       macd_signal      macd   bb_middle    bb_upper    bb_lower  \
# 0       17.303938  0.262689  372.687997  417.839989  327.536006
# 1       16.444422  0.223167  372.769331  417.823361  327.715302
# 2       15.771102  0.263538  373.152498  418.285384  328.019612
# 3       15.255158  0.297660  372.088664  415.232021  328.945307
# 4       14.565501  0.259995  370.805331  413.141275  328.469388
# ...           ...       ...         ...         ...         ...
# 4520    -1.212932  0.503113   25.520000   30.182071   20.857929
# 4521    -1.263172  0.524201   25.176500   29.521681   20.831319
# 4522    -1.272160  0.588671   24.909000   28.627822   21.190178
# 4523    -1.255112  0.629360   24.652500   27.667472   21.637528
# 4524    -1.234297  0.635248   24.417500   26.964604   21.870395
#
#       future_percent  future_magnitude  future_direction
# 0          -3.053760          0.223228                 0
# 1           5.090023          0.374185                 1
# 2           0.683382          0.047502                 1
# 3          -4.346763          0.319084                 0
# 4          -0.949774          0.067250                 0
# ...              ...               ...               ...
# 4520        0.925514          0.029893                 1
# 4521        7.467253          0.251575                 1
# 4522       -0.812681          0.026069                 0
# 4523       -3.727980          0.124861                 0
# 4524       -2.510639          0.083608                 0
#
# [4525 rows x 25 columns]

# %% [markdown]
# ### Plot Stock Price

# %%
ticker = 'TSLA'
plotting_data = train_data[train_data['stock_name'] == ticker]
plotting_data.reset_index(inplace=True)

# %%
fig, axs = plt.subplots(5, figsize=(12, 15), gridspec_kw={'height_ratios': [2, 2, 1, 1, 1]})

# Plot stock price
axs[0].plot(plotting_data.index, plotting_data['close'], label="Closing Price", color='black', linewidth=2)
axs[0].set_title(f"Stock Price of {ticker}")
axs[0].set_ylabel("Price")
axs[0].legend(loc="upper right")

# Plot percent change with volume
axs[1].bar(plotting_data.index, plotting_data['volume'], label=f"Volume", color='grey', alpha=0.3)
axs[1].plot(plotting_data.index, plotting_data['percent_close'], label="Closing Price", color='black', linewidth=2)
axs[1].plot(plotting_data.index, plotting_data['sma'], label="Simple moving average", color='cyan', alpha=0.5)
axs[1].plot(plotting_data.index, plotting_data['ema'], label="Exponential moving average", color='magenta', alpha=0.5)
axs[1].set_title(f"Normalized Percent Change in Closing Price of {ticker}")
axs[1].set_ylabel("Percent")
axs[1].legend(loc="upper right")

# Plot RSI
axs[2].plot(plotting_data.index, plotting_data['rsi'], label="RSI", color='purple', linewidth=2)
axs[2].axhline(0.8, linestyle='dashed', color='red', alpha=0.7)
axs[2].axhline(0.2, linestyle='dashed', color='green', alpha=0.7)
axs[4].set_ylim([0, 1])
axs[2].set_title("Normalized Relative Strength Index (RSI)")
axs[2].set_ylabel("RSI")
axs[2].legend(loc="upper right")

# Plot MACD
axs[3].plot(plotting_data.index, 2*(plotting_data['macd']-0.5), label="MACD *adjusted for display", color='black', linewidth=2)
axs[3].bar(plotting_data.index, 2*(plotting_data['macd']-0.5), 
           color=['green' if v >= 0 else 'red' for v in 2*(plotting_data['macd']-0.5)], 
           alpha=0.5)
axs[3].axhline(0, color='black', alpha=0.5)
axs[4].set_ylim([-1, 1])
axs[3].set_title("Normalized Moving Average Convergence Divergence (MACD)")
axs[3].set_ylabel("MACD")
axs[3].legend(loc="upper right")

# Plot Sentiment
axs[4].plot(plotting_data.index, 2*(plotting_data['sentiment']-0.5), label="Sentiment *adjusted for display", color='black', linewidth=2)
axs[4].bar(plotting_data.index, 2*(plotting_data['sentiment']-0.5), 
           color=['blue' if v >= 0 else 'pink' for v in 2*(plotting_data['sentiment']-0.5)], 
           alpha=0.5)
axs[4].axhline(0, color='black', alpha=0.5)
axs[4].set_ylim([-1, 1])
axs[4].set_title("Normalized Sentiment Score")
axs[4].set_ylabel("Sentiment")
axs[4].legend(loc="upper right")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Define Model

# %%
class LSTM_Model(tf.keras.Model):
    def __init__(self, num_layers, hidden_dim, dropout_rate=0.1):
        super(LSTM_Model, self).__init__()
        
        self.num_layers = num_layers
        self.hidden_dim = hidden_dim

        self.lstm_layers = [
            tf.keras.layers.LSTM(
                hidden_dim,
                activation='tanh',
                return_sequences=True
            ) for _ in range(num_layers - 1)
        ]

        self.last_lstm = tf.keras.layers.LSTM(
            hidden_dim,
            activation='tanh',
            return_sequences=False
        )

        self.dropout = tf.keras.layers.Dropout(dropout_rate)
        self.dense1 = tf.keras.layers.Dense(hidden_dim // 2, activation="relu")

        self.price_change_output = tf.keras.layers.Dense(1, activation="linear", name="price_change_output")  # Regression
        self.direction_output = tf.keras.layers.Dense(1, activation="sigmoid", name="direction_output")  # Classification

    def call(self, x):
        for lstm_layer in self.lstm_layers:
            x = lstm_layer(x)
            x = self.dropout(x)
        
        x = self.last_lstm(x)
        x = self.dropout(x)

        x = self.dense1(x)
        x = self.dropout(x)

        return {
            "price_change_output": self.price_change_output(x),  # Regression Output
            "direction_output": self.direction_output(x)  # Classification Output
        }

# %% [markdown]
# ### Train Model

# %%
num_layers = 4
hidden_dim = 64
dropout_rate = 0.1

model = LSTM_Model(num_layers, hidden_dim, dropout_rate)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
    loss={
        "price_change_output": tf.keras.losses.MeanSquaredError(),
        "direction_output": tf.keras.losses.BinaryCrossentropy()
    },
    loss_weights={
        "price_change_output": 0.2, 
        "direction_output": 0.8},
    metrics={
        "price_change_output": ["mae"],
        "direction_output": ["accuracy"]
    }
)

history = model.fit(
    x=train_x,
    y={
        "price_change_output": train_y[:, 0],
        "direction_output": train_y[:, 1]
    },
    epochs=30,
    batch_size=32,
    validation_data=(
        test_x,
        {
            "price_change_output": test_y[:, 0], 
            "direction_output": test_y[:, 1]
        }
    )
)
# Out:
# Epoch 1/30
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 39s 187ms/step - direction_output_accuracy: 0.5258 - direction_output_loss: 0.6911 - loss: 0.5606 - price_change_output_loss: 0.0388 - price_change_output_mae: 0.1412 - val_direction_output_accuracy: 0.4760 - val_direction_output_loss: 0.6940 - val_loss: 0.5595 - val_price_change_output_loss: 0.0215 - val_price_change_output_mae: 0.1071
# Epoch 2/30
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 22s 152ms/step - direction_output_accuracy: 0.5385 - direction_output_loss: 0.6897 - loss: 0.5583 - price_change_output_loss: 0.0326 - price_change_output_mae: 0.1333 - val_direction_output_accuracy: 0.4573 - val_direction_output_loss: 0.6965 - val_loss: 0.5613 - val_price_change_output_loss: 0.0214 - val_price_change_output_mae: 0.1108
# Epoch 3/30
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 21s 150ms/step - direction_output_accuracy: 0.5408 - direction_output_loss: 0.6884 - loss: 0.5572 - price_change_output_loss: 0.0320 - price_change_output_mae: 0.1344 - val_direction_output_accuracy: 0.4440 - val_direction_output_loss: 0.6986 - val_loss: 0.5629 - val_price_change_output_loss: 0.0214 - val_price_change_output_mae: 0.1117
# Epoch 4/30
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 20s 138ms/step - direction_output_accuracy: 0.5385 - direction_output_loss: 0.6881 - loss: 0.5567 - price_change_output_loss: 0.0310 - price_change_output_mae: 0.1324 - val_direction_output_accuracy: 0.4453 - val_direction_output_loss: 0.7003 - val_loss: 0.5642 - val_price_change_output_loss: 0.0215 - val_price_change_output_mae: 0.1129
# Epoch 5/30
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 24s 167ms/step - direction_output_accuracy: 0.5378 - direction_output_loss: 0.6878 - loss: 0.5565 - price_change_output_loss: 0.0311 - price_change_output_mae: 0.1334 - val_direction_output_accuracy: 0.4440 - val_direction_output_loss: 0.7026 - val_loss: 0.5660 - val_price_change_output_loss: 0.0218 - val_price_change_output_mae: 0.1144
# Epoch 6/30
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 26s 181ms/step - direction_output_accuracy: 0.5405 - direction_output_loss: 0.6877 - loss: 0.5563 - price_change_output_loss: 0.0307 - price_change_output_mae: 0.1316 - val_direction_output_accuracy: 0.4520 - val_direction_output_loss: 0.7035 - val_loss: 0.5668 - val_price_change_output_loss: 0.0222 - val_price_change_output_mae: 0.1174
# Epoch 7/30
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 26s 181ms/step - direction_output_accuracy: 0.5418 - direction_output_loss: 0.6874 - loss: 0.5560 - price_change_output_loss: 0.0307 - price_change_output_mae: 0.1320 - val_direction_output_accuracy: 0.4613 - val_direction_output_loss: 0.7037 - val_loss: 0.5669 - val_price_change_output_loss: 0.0223 - val_price_change_output_mae: 0.1177
# Epoch 8/30
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 27s 192ms/step - direction_output_accuracy: 0.5428 - direction_output_loss: 0.6873 - loss: 0.5559 - price_change_output_loss: 0.0307 - price_change_output_mae: 0.1324 - val_direction_output_accuracy: 0.4467 - val_direction_output_loss: 0.7054 - val_loss: 0.5681 - val_price_change_output_loss: 0.0215 - val_price_change_output_mae: 0.1132
# Epoch 9/30
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 25s 168ms/step - direction_output_accuracy: 0.5406 - direction_output_loss: 0.6871 - loss: 0.5559 - price_change_output_loss: 0.0307 - price_change_output_mae: 0.1320 - val_direction_output_accuracy: 0.4533 - val_direction_output_loss: 0.7053 - val_loss: 0.5680 - val_price_change_output_loss: 0.0217 - val_price_change_output_mae: 0.1138
# Epoch 10/30
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 22s 154ms/step - direction_output_accuracy: 0.5429 - direction_output_loss: 0.6868 - loss: 0.5556 - price_change_output_loss: 0.0308 - price_change_output_mae: 0.1315 - val_direction_output_accuracy: 0.4533 - val_direction_output_loss: 0.7057 - val_loss: 0.5683 - val_price_change_output_loss: 0.0214 - val_price_change_output_mae: 0.1124
# Epoch 11/30
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 20s 142ms/step - direction_output_accuracy: 0.5450 - direction_output_loss: 0.6865 - loss: 0.5553 - price_change_output_loss: 0.0304 - price_change_output_mae: 0.1310 - val_direction_output_accuracy: 0.4547 - val_direction_output_loss: 0.7063 - val_loss: 0.5687 - val_price_change_output_loss: 0.0212 - val_price_change_output_mae: 0.1107
# Epoch 12/30
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 22s 157ms/step - direction_output_accuracy: 0.5445 - direction_output_loss: 0.6865 - loss: 0.5553 - price_change_output_loss: 0.0304 - price_change_output_mae: 0.1306 - val_direction_output_accuracy: 0.4560 - val_direction_output_loss: 0.7064 - val_loss: 0.5689 - val_price_change_output_loss: 0.0215 - val_price_change_output_mae: 0.1129
# Epoch 13/30
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 25s 170ms/step - direction_output_accuracy: 0.5396 - direction_output_loss: 0.6864 - loss: 0.5552 - price_change_output_loss: 0.0305 - price_change_output_mae: 0.1303 - val_direction_output_accuracy: 0.4573 - val_direction_output_loss: 0.7071 - val_loss: 0.5693 - val_price_change_output_loss: 0.0213 - val_price_change_output_mae: 0.1118
# Epoch 14/30
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 23s 156ms/step - direction_output_accuracy: 0.5429 - direction_output_loss: 0.6860 - loss: 0.5549 - price_change_output_loss: 0.0303 - price_change_output_mae: 0.1293 - val_direction_output_accuracy: 0.4493 - val_direction_output_loss: 0.7081 - val_loss: 0.5702 - val_price_change_output_loss: 0.0217 - val_price_change_output_mae: 0.1145
# Epoch 15/30
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 22s 152ms/step - direction_output_accuracy: 0.5436 - direction_output_loss: 0.6861 - loss: 0.5549 - price_change_output_loss: 0.0305 - price_change_output_mae: 0.1301 - val_direction_output_accuracy: 0.4587 - val_direction_output_loss: 0.7077 - val_loss: 0.5698 - val_price_change_output_loss: 0.0215 - val_price_change_output_mae: 0.1125
# Epoch 16/30
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 22s 151ms/step - direction_output_accuracy: 0.5437 - direction_output_loss: 0.6858 - loss: 0.5547 - price_change_output_loss: 0.0304 - price_change_output_mae: 0.1303 - val_direction_output_accuracy: 0.4693 - val_direction_output_loss: 0.7067 - val_loss: 0.5690 - val_price_change_output_loss: 0.0217 - val_price_change_output_mae: 0.1145
# Epoch 17/30
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 24s 169ms/step - direction_output_accuracy: 0.5446 - direction_output_loss: 0.6859 - loss: 0.5548 - price_change_output_loss: 0.0306 - price_change_output_mae: 0.1302 - val_direction_output_accuracy: 0.4653 - val_direction_output_loss: 0.7050 - val_loss: 0.5678 - val_price_change_output_loss: 0.0219 - val_price_change_output_mae: 0.1153
# Epoch 18/30
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 20s 142ms/step - direction_output_accuracy: 0.5447 - direction_output_loss: 0.6853 - loss: 0.5543 - price_change_output_loss: 0.0303 - price_change_output_mae: 0.1301 - val_direction_output_accuracy: 0.4720 - val_direction_output_loss: 0.7059 - val_loss: 0.5684 - val_price_change_output_loss: 0.0219 - val_price_change_output_mae: 0.1151
# Epoch 19/30
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 20s 141ms/step - direction_output_accuracy: 0.5459 - direction_output_loss: 0.6853 - loss: 0.5543 - price_change_output_loss: 0.0303 - price_change_output_mae: 0.1295 - val_direction_output_accuracy: 0.4613 - val_direction_output_loss: 0.7079 - val_loss: 0.5699 - val_price_change_output_loss: 0.0216 - val_price_change_output_mae: 0.1132
# Epoch 20/30
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 20s 138ms/step - direction_output_accuracy: 0.5475 - direction_output_loss: 0.6850 - loss: 0.5541 - price_change_output_loss: 0.0303 - price_change_output_mae: 0.1296 - val_direction_output_accuracy: 0.4867 - val_direction_output_loss: 0.7017 - val_loss: 0.5650 - val_price_change_output_loss: 0.0220 - val_price_change_output_mae: 0.1151
# Epoch 21/30
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 19s 134ms/step - direction_output_accuracy: 0.5502 - direction_output_loss: 0.6849 - loss: 0.5540 - price_change_output_loss: 0.0305 - price_change_output_mae: 0.1309 - val_direction_output_accuracy: 0.4947 - val_direction_output_loss: 0.7017 - val_loss: 0.5650 - val_price_change_output_loss: 0.0221 - val_price_change_output_mae: 0.1146
# Epoch 22/30
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 19s 134ms/step - direction_output_accuracy: 0.5530 - direction_output_loss: 0.6846 - loss: 0.5538 - price_change_output_loss: 0.0307 - price_change_output_mae: 0.1312 - val_direction_output_accuracy: 0.4933 - val_direction_output_loss: 0.7023 - val_loss: 0.5652 - val_price_change_output_loss: 0.0221 - val_price_change_output_mae: 0.1162
# Epoch 23/30
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 20s 137ms/step - direction_output_accuracy: 0.5496 - direction_output_loss: 0.6849 - loss: 0.5541 - price_change_output_loss: 0.0309 - price_change_output_mae: 0.1309 - val_direction_output_accuracy: 0.5253 - val_direction_output_loss: 0.6983 - val_loss: 0.5624 - val_price_change_output_loss: 0.0240 - val_price_change_output_mae: 0.1239
# Epoch 24/30
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 22s 155ms/step - direction_output_accuracy: 0.5496 - direction_output_loss: 0.6848 - loss: 0.5540 - price_change_output_loss: 0.0309 - price_change_output_mae: 0.1318 - val_direction_output_accuracy: 0.5213 - val_direction_output_loss: 0.6976 - val_loss: 0.5614 - val_price_change_output_loss: 0.0226 - val_price_change_output_mae: 0.1181
# Epoch 25/30
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 20s 137ms/step - direction_output_accuracy: 0.5551 - direction_output_loss: 0.6843 - loss: 0.5535 - price_change_output_loss: 0.0307 - price_change_output_mae: 0.1317 - val_direction_output_accuracy: 0.5093 - val_direction_output_loss: 0.7006 - val_loss: 0.5640 - val_price_change_output_loss: 0.0223 - val_price_change_output_mae: 0.1171
# Epoch 26/30
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 20s 137ms/step - direction_output_accuracy: 0.5512 - direction_output_loss: 0.6843 - loss: 0.5537 - price_change_output_loss: 0.0316 - price_change_output_mae: 0.1332 - val_direction_output_accuracy: 0.5107 - val_direction_output_loss: 0.6991 - val_loss: 0.5627 - val_price_change_output_loss: 0.0222 - val_price_change_output_mae: 0.1128
# Epoch 27/30
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 20s 140ms/step - direction_output_accuracy: 0.5447 - direction_output_loss: 0.6844 - loss: 0.5536 - price_change_output_loss: 0.0306 - price_change_output_mae: 0.1310 - val_direction_output_accuracy: 0.4827 - val_direction_output_loss: 0.7063 - val_loss: 0.5685 - val_price_change_output_loss: 0.0219 - val_price_change_output_mae: 0.1139
# Epoch 28/30
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 19s 134ms/step - direction_output_accuracy: 0.5533 - direction_output_loss: 0.6835 - loss: 0.5530 - price_change_output_loss: 0.0308 - price_change_output_mae: 0.1308 - val_direction_output_accuracy: 0.4827 - val_direction_output_loss: 0.7040 - val_loss: 0.5669 - val_price_change_output_loss: 0.0228 - val_price_change_output_mae: 0.1181
# Epoch 29/30
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 19s 135ms/step - direction_output_accuracy: 0.5623 - direction_output_loss: 0.6830 - loss: 0.5527 - price_change_output_loss: 0.0316 - price_change_output_mae: 0.1332 - val_direction_output_accuracy: 0.4760 - val_direction_output_loss: 0.7135 - val_loss: 0.5738 - val_price_change_output_loss: 0.0218 - val_price_change_output_mae: 0.1120
# Epoch 30/30
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 19s 134ms/step - direction_output_accuracy: 0.5596 - direction_output_loss: 0.6822 - loss: 0.5520 - price_change_output_loss: 0.0313 - price_change_output_mae: 0.1323 - val_direction_output_accuracy: 0.5227 - val_direction_output_loss: 0.7034 - val_loss: 0.5657 - val_price_change_output_loss: 0.0232 - val_price_change_output_mae: 0.1197

# %% [markdown]
# ### Plot Performance

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(len(loss))

plt.figure(figsize=(12, 6))
plt.plot(epochs_range, loss, label='Training')
plt.plot(epochs_range, val_loss, label='Validation')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('LSTM - Training & Validation Loss')
plt.legend(loc='upper right')
plt.show()

# %%
direction_accuracy = history.history['direction_output_accuracy']
val_direction_accuracy = history.history['val_direction_output_accuracy']

plt.figure(figsize=(12, 6))
plt.plot(direction_accuracy, label="Training")
plt.plot(val_direction_accuracy, label="Validation")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("LSTM - Direction Accuracy")
plt.legend(loc='upper right')
plt.show()

# %%
price_change_output_mae = history.history['price_change_output_mae']
val_price_change_output_mae = history.history['val_price_change_output_mae']

plt.figure(figsize=(12, 6))
plt.plot(price_change_output_mae, label="Training")
plt.plot(val_price_change_output_mae, label="Validation")
plt.xlabel("Epochs")
plt.ylabel("Mean Absolute Error")
plt.title("LSTM - Magnitude Error")
plt.legend(loc='upper right')
plt.show()

# %%
train_pred = model.predict(train_x)
train_pred_magnitude= train_pred['price_change_output']
train_pred_direction = (train_pred['direction_output'] > 0.5).astype(int)
train_actual_magnitude = train_y[:, 0]
train_actual_direction = train_y[:, 1]

test_pred = model.predict(test_x)
test_pred_magnitude = test_pred['price_change_output']
test_pred_direction = (test_pred['direction_output'] > 0.5).astype(int)
test_actual_magnitude = test_y[:, 0]
test_actual_direction = test_y[:, 1]
# Out:
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

axs[0].scatter(train_pred_magnitude, train_actual_magnitude, alpha=0.5, label="Train Data")
axs[0].set_xlabel("Predicted Price Change")
axs[0].set_ylabel("Actual Price Change")
axs[0].set_title("Train Set: Predicted vs. Actual")
axs[0].axline((0, 0), slope=1, color="red", linestyle="dashed")  # Reference line
axs[0].set_xlim([0,1])
axs[0].set_ylim([0,1])

axs[1].scatter(test_pred_magnitude, test_actual_magnitude, alpha=0.5, label="Test Data")
axs[1].set_xlabel("Predicted Price Change")
axs[1].set_ylabel("Actual Price Change")
axs[1].set_title("Test Set: Predicted vs. Actual")
axs[1].axline((0, 0), slope=1, color="red", linestyle="dashed")  # Reference line
axs[1].set_xlim([0,1])
axs[1].set_ylim([0,1])

plt.tight_layout()
plt.show()

# %%
train_cm = confusion_matrix(train_actual_direction, train_pred_direction)
test_cm = confusion_matrix(test_actual_direction, test_pred_direction)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

sns.heatmap(train_cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=["Down (0)", "Up (1)"], yticklabels=["Down (0)", "Up (1)"], ax=axes[0])
axes[0].set_xlabel("Predicted Label")
axes[0].set_ylabel("True Label")
axes[0].set_title("Train Set: Confusion Matrix")

sns.heatmap(test_cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=["Down (0)", "Up (1)"], yticklabels=["Down (0)", "Up (1)"], ax=axes[1])
axes[1].set_xlabel("Predicted Label")
axes[1].set_ylabel("True Label")
axes[1].set_title("Test Set: Confusion Matrix")

plt.tight_layout()
plt.show()

# %%
train_report = classification_report(train_actual_direction, train_pred_direction, target_names=["Down (0)", "Up (1)"])
test_report = classification_report(test_actual_direction, test_pred_direction, target_names=["Down (0)", "Up (1)"])

print("Train Classification Report:\n", train_report)
print("\nTest Classification Report:\n", test_report)
# Out:
# Train Classification Report:
#                precision    recall  f1-score   support
#
#     Down (0)       0.57      0.71      0.63      2361
#       Up (1)       0.57      0.41      0.48      2164
#
#     accuracy                           0.57      4525
#    macro avg       0.57      0.56      0.56      4525
# weighted avg       0.57      0.57      0.56      4525
#
#
# Test Classification Report:
#                precision    recall  f1-score   support
#
#     Down (0)       0.62      0.53      0.57       453
#       Up (1)       0.42      0.52      0.46       297
#
#     accuracy                           0.52       750
#    macro avg       0.52      0.52      0.52       750
# weighted avg       0.54      0.52      0.53       750

# %% [markdown]
# ### Calculate Stock Price Predictions

# %%
train_pred_percent = train_pred_magnitude * (2 * train_pred_direction - 1)
test_pred_percent = test_pred_magnitude * (2 * test_pred_direction - 1)

# %%
train_data['predicted_percent_close'] = np.nan
for ticker in np.unique(train_tickers):
    stock_indices = np.where(train_tickers == ticker)[0]
    train_data.loc[train_data['stock_name'] == ticker, 'predicted_percent_close'] = train_pred_percent[stock_indices]

# %%
test_data['predicted_percent_close'] = np.nan
for ticker in np.unique(test_tickers):
    stock_indices = np.where(test_tickers == ticker)[0]
    test_data.loc[test_data['stock_name'] == ticker, 'predicted_percent_close'] = test_pred_percent[stock_indices]

# %%
train_data['predicted_close'] = np.nan

for ticker in np.unique(train_tickers):
    scaler = scalers[ticker]
    
    stock_rows = train_data['stock_name'] == ticker
    stock_predicted_percent = train_data.loc[stock_rows, 'predicted_percent_close'].values.reshape(-1, 1)

    if len(stock_predicted_percent) > 0:
        # Create dummy feature set for inverse transformation
        dummy_features = np.zeros((len(stock_predicted_percent), len(feature_cols)))  
        
        # Denormalize and compute predicted close price
        denormalized_predicted_percent = scaler.inverse_transform(
            np.column_stack([dummy_features, stock_predicted_percent])
        )[:, -1]

        # Shift the actual close price by one day (previous close)
        prev_close_price = train_data.loc[stock_rows, 'close'].shift(1)

        # Compute predicted close price
        train_data.loc[stock_rows, 'predicted_close'] = prev_close_price * (1 + denormalized_predicted_percent / 100)

# %%
test_data['predicted_close'] = np.nan

for ticker in np.unique(test_tickers):
    scaler = scalers[ticker]
    
    stock_rows = test_data['stock_name'] == ticker
    stock_predicted_percent = test_data.loc[stock_rows, 'predicted_percent_close'].values.reshape(-1, 1)

    if len(stock_predicted_percent) > 0:
        # Create dummy feature set for inverse transformation
        dummy_features = np.zeros((len(stock_predicted_percent), len(feature_cols)))  
        
        # Denormalize and compute predicted close price
        denormalized_predicted_percent = scaler.inverse_transform(
            np.column_stack([dummy_features, stock_predicted_percent])
        )[:, -1]

        # Shift the actual close price by one day (previous close)
        prev_close_price = test_data.loc[stock_rows, 'close'].shift(1)

        # Compute predicted close price
        test_data.loc[stock_rows, 'predicted_close'] = prev_close_price * (1 + denormalized_predicted_percent / 100)

# %%
train_data['forecast'] = np.nan

for ticker in np.unique(train_tickers):
    stock_rows = train_data['stock_name'] == ticker
    stock_df = train_data.loc[stock_rows].copy()

    # Get the first actual close price (the starting reference point)
    first_actual_close = stock_df['close'].iloc[0]

    # Initialize an array to store accumulated predictions
    accumulated_prices = [first_actual_close]

    # Compute accumulated forecast
    for i in range(1, len(stock_df)):
        predicted_change = stock_df['predicted_close'].iloc[i] - stock_df['close'].iloc[i-1]
        new_forecast_price = accumulated_prices[-1] + predicted_change
        accumulated_prices.append(new_forecast_price)

    # Store results back in the DataFrame
    train_data.loc[stock_rows, 'forecast'] = accumulated_prices

# %%
test_data['forecast'] = np.nan

for ticker in np.unique(test_tickers):
    stock_rows = test_data['stock_name'] == ticker
    stock_df = test_data.loc[stock_rows].copy()

    # Get the first actual close price (the starting reference point)
    first_actual_close = stock_df['close'].iloc[0]

    # Initialize an array to store accumulated predictions
    accumulated_prices = [first_actual_close]

    # Compute accumulated forecast
    for i in range(1, len(stock_df)):
        predicted_change = stock_df['predicted_close'].iloc[i] - stock_df['close'].iloc[i-1]
        new_forecast_price = accumulated_prices[-1] + predicted_change
        accumulated_prices.append(new_forecast_price)

    # Store results back in the DataFrame
    test_data.loc[stock_rows, 'forecast'] = accumulated_prices

# %% [markdown]
# ### Plot Predictions

# %%
grid_size = (5, 5)
fig, axes = plt.subplots(grid_size[0], grid_size[1], figsize=(20, 20))
axes = axes.flatten()

fig.suptitle('Training Predictions', fontsize=20, fontweight='bold')

for i, stock in enumerate(tickers):

    stock_df = train_data[train_data['stock_name'] == stock]
    stock_df.reset_index(inplace=True)

    ax = axes[i]
    ax.plot(stock_df.index, stock_df['close'], label='Actual')
    ax.plot(stock_df.index, stock_df['predicted_close'], label='Predicted')
    ax.set_title(f'{stock}')
    ax.set_xlabel('Day')
    ax.set_ylabel('Price')
    ax.legend(loc='upper right')

for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.show()

# %%
grid_size = (5, 5)
fig, axes = plt.subplots(grid_size[0], grid_size[1], figsize=(20, 20))
axes = axes.flatten()

fig.suptitle('Testing Predictions', fontsize=20, fontweight='bold')

for i, stock in enumerate(tickers):

    stock_df = test_data[test_data['stock_name'] == stock]
    stock_df.reset_index(inplace=True)

    ax = axes[i]
    ax.plot(stock_df.index, stock_df['close'], label='Actual')
    ax.plot(stock_df.index, stock_df['predicted_close'], label='Predicted')
    ax.set_title(f'{stock}')
    ax.set_xlabel('Day')
    ax.set_ylabel('Price')
    ax.legend(loc='upper right')

for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout(rect=[0, 0, 1, 0.98]) 
plt.show()

# %%
stock = "AAPL"

stock_df = train_data[train_data['stock_name'] == stock]
stock_df.reset_index(inplace=True)

plt.figure(figsize=(12, 6))
plt.plot(stock_df.index, stock_df['close'], label='Actual')
plt.plot(stock_df.index, stock_df['predicted_close'], label='Predicted')
plt.xlabel('Day')
plt.ylabel('Price')
plt.title(f'{stock} Training Predictions')
plt.legend(loc='upper right')

plt.show()

# %%
stock = "AAPL"

stock_df = test_data[test_data['stock_name'] == stock]
stock_df.reset_index(inplace=True)

plt.figure(i, figsize=(12, 6))
plt.plot(stock_df.index, stock_df['close'], label='Actual')
plt.plot(stock_df.index, stock_df['predicted_close'], label='Predicted')
plt.xlabel('Day')
plt.ylabel('Price')
plt.title(f'{stock} Testing Predictions')
plt.legend(loc='upper right')

plt.show()

# %% [markdown]
# ### Plot Forecast

# %%
grid_size = (5, 5)
fig, axes = plt.subplots(grid_size[0], grid_size[1], figsize=(20, 20))
axes = axes.flatten()

fig.suptitle('Accumulated Training Predictions', fontsize=20, fontweight='bold')

for i, stock in enumerate(tickers):

    stock_df = train_data[train_data['stock_name'] == stock].copy()
    stock_df.reset_index(inplace=True)
  
    ax = axes[i]
    
    colors = ['green' if v > 0 else 'red' for v in stock_df['predicted_percent_close']]
    
    ax.bar(stock_df.index, stock_df['forecast'], color=colors, alpha=0.3)
    ax.plot(stock_df.index, stock_df['close'], label='Actual', color='black')
    ax.plot(stock_df.index, stock_df['forecast'], label='Predicted', color='grey')
    ax.set_title(f'{stock}')
    ax.set_xlabel('Day')
    ax.set_ylabel('Price')
    ax.legend(loc='upper right')

for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.show()

# %%
grid_size = (5, 5)
fig, axes = plt.subplots(grid_size[0], grid_size[1], figsize=(20, 20))
axes = axes.flatten()

fig.suptitle('Accumulated Testing Predictions', fontsize=20, fontweight='bold')

for i, stock in enumerate(tickers):

    stock_df = test_data[test_data['stock_name'] == stock].copy()
    stock_df.reset_index(inplace=True)
  
    ax = axes[i]
    
    colors = ['green' if v > 0 else 'red' for v in stock_df['predicted_percent_close']]

    ax.bar(stock_df.index, stock_df['forecast'], color=colors, alpha=0.3)
    ax.plot(stock_df.index, stock_df['close'], label='Actual', color='black')
    ax.plot(stock_df.index, stock_df['forecast'], label='Prediction', color='grey')
    ax.set_title(f'{stock}')
    ax.set_xlabel('Day')
    ax.set_ylabel('Price')
    ax.legend(loc='upper right')

for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.show()

# %%
stock = "AAPL"

stock_df = train_data[train_data['stock_name'] == stock]
stock_df.reset_index(inplace=True)

plt.figure(figsize=(12, 6))
plt.bar(stock_df.index, stock_df['forecast'], 
        color=['green' if v > 0 else 'red' for v in stock_df['predicted_percent_close']], 
        alpha=0.3)
plt.plot(stock_df.index, stock_df['close'], label='Actual', color='black')
plt.plot(stock_df.index, stock_df['forecast'], label='Predicted', color='grey')
plt.xlabel('Day')
plt.ylabel('Price')
plt.title(f'{stock} Accumulated Training Predictions')
plt.legend(loc='upper right')
plt.show()

# %%
stock = "AAPL"

stock_df = test_data[test_data['stock_name'] == stock]
stock_df.reset_index(inplace=True)

plt.figure(figsize=(12, 6))
plt.bar(stock_df.index, stock_df['forecast'], 
        color=['green' if v > 0 else 'red' for v in stock_df['predicted_percent_close']], 
        alpha=0.3)
plt.plot(stock_df.index, stock_df['close'], label='Actual', color='black')
plt.plot(stock_df.index, stock_df['forecast'], label='Predicted', color='grey')
plt.xlabel('Day')
plt.ylabel('Price')
plt.title(f'{stock} Accumulated Testing Predictions')
plt.legend(loc='upper right')
plt.show()
