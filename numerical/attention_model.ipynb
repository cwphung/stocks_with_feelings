# %% [markdown]
# # Attention Model

# %%
import sys
import warnings

if not sys.warnoptions:
    warnings.simplefilter('ignore')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf

from numerical_preprocessing import *
# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

sns.set()
tf.random.set_seed(1234)

# %% [markdown]
# ### Load Dataset and Select Ticker

# %%
df = pd.read_csv("stock_yfinance_data.csv")

ticker = 'TSLA'
df = clean_stock_data(df, ticker=ticker)

df.head()
# Out:
#          date        open        high         low       close   adj_close  \
# 0  2021-09-30  260.333344  263.043335  258.333344  258.493347  258.493347
# 1  2021-10-01  259.466675  260.260010  254.529999  258.406677  258.406677
# 2  2021-10-04  265.500000  268.989990  258.706665  260.510010  260.510010
# 3  2021-10-05  261.600006  265.769989  258.066681  260.196655  260.196655
# 4  2021-10-06  258.733337  262.220001  257.739990  260.916656  260.916656
#
#      volume
# 0  53868000
# 1  51094200
# 2  91449900
# 3  55297800
# 4  43898400

# %% [markdown]
# ### Calculate technical analysis features

# %%
df['rdr'] = relative_daily_range(df)
df['sma'] = simple_moving_average(df)
df['ema'] = exponential_moving_average(df)
df['rsi'] = calculate_rsi(df)
df['macd_line'] , df['macd_signal'], df['macd'] = calculate_macd(df)
df['bb_middle'], df['bb_upper'], df['bb_lower'] = bollinger_bands(df)
df.dropna(inplace=True)
df.head()
# Out:
#           date        open        high         low       close   adj_close  \
# 19  2021-10-27  346.553345  356.959991  343.593323  345.953339  345.953339
# 20  2021-10-28  356.103333  360.333344  351.399994  359.013336  359.013336
# 21  2021-10-29  360.619995  371.736664  357.736664  371.333344  371.333344
# 22  2021-11-01  381.666656  403.250000  372.886658  402.863342  402.863342
# 23  2021-11-02  386.453339  402.863342  382.000000  390.666656  390.666656
#
#        volume       rdr         sma         ema        rsi  macd_line  \
# 19  115579500  0.121020  283.829501  293.487203  92.846316  18.892766
# 20   81639600  0.080881  288.855501  299.727787  96.118171  21.687444
# 21   89755200  0.122811  294.501834  306.547364  96.459875  24.612650
# 22  168146100  0.208668  301.619501  315.720314  97.129203  29.139205
# 23  128213400  0.143381  308.143001  322.858061  89.346741  31.380625
#
#     macd_signal       macd   bb_middle    bb_upper    bb_lower
# 19    11.140409   7.752357  283.829501  341.251886  226.407117
# 20    13.249816   8.437628  288.855501  354.015698  223.695304
# 21    15.522383   9.090267  294.501834  367.635649  221.368019
# 22    18.245747  10.893457  301.619501  387.433479  215.805523
# 23    20.872723  10.507902  308.143001  400.300312  215.985690

# %% [markdown]
# ### Normalize features based on moving window

# %%
feature_col = ['open', 'high', 'low', 'close', 'volume', 'rdr', 'sma', 'ema', 'rsi', 'macd']
norm_df = pd.DataFrame({})
window = 30 #days

for col in feature_col:
    norm_df[col] = calculate_moving_normalized(df, col, window)

norm_df = norm_df.iloc[window:].reset_index(drop=True)
norm_df
# Out:
#          open      high       low     close    volume       rdr       sma  \
# 0    0.253886  0.184133  0.194596  0.000000  0.171469  0.469399  0.836295
# 1    0.031086  0.000000  0.120188  0.058511  0.173057  0.246865  0.814693
# 2    0.000000  0.000000  0.003452  0.000000  0.306118  0.402166  0.780642
# 3    0.000000  0.000000  0.000000  0.000000  0.251370  0.197753  0.744560
# 4    0.028368  0.044536  0.000000  0.064407  0.282035  0.328413  0.690125
# ..        ...       ...       ...       ...       ...       ...       ...
# 198  0.268890  0.220030  0.177711  0.130913  0.460763  0.492524  0.575938
# 199  0.000000  0.209429  0.114709  0.148300  0.341349  0.624178  0.422977
# 200  0.301481  0.327847  0.295432  0.327586  0.433537  0.459925  0.245138
# 201  0.308557  0.344089  0.296938  0.452908  0.283043  0.476851  0.064204
# 202  0.299781  0.202592  0.001004  0.000000  0.790656  0.880588  0.017210
#
#           ema       rsi      macd
# 0    0.874582  0.056990  0.091122
# 1    0.832022  0.000000  0.097195
# 2    0.736376  0.000000  0.055355
# 3    0.616433  0.045706  0.037074
# 4    0.459921  0.072020  0.064626
# ..        ...       ...       ...
# 198  0.824818  0.670916  0.458126
# 199  0.648564  0.638954  0.312073
# 200  0.560669  0.618639  0.304625
# 201  0.536218  0.611746  0.365305
# 202  0.350900  0.342749  0.227829
#
# [203 rows x 10 columns]

# %% [markdown]
# ### Plot Stock Price

# %%
fig, axs = plt.subplots(3, figsize=(12, 10), gridspec_kw={'height_ratios': [3, 1, 1]})

# Plot stock price with volume
vol_scale = 1e6
axs[0].bar(df.index, df['volume']/vol_scale, label=f"Volume (1e{int(np.log10(vol_scale))})", color='grey', alpha=0.3)
axs[0].plot(df.index, df['close'], label="Closing Price", color='black', linewidth=2)
axs[0].plot(df.index, df['sma'], label="Simple moving average", color='cyan', alpha=0.5)
axs[0].plot(df.index, df['ema'], label="Exponential moving average", color='magenta', alpha=0.5)
axs[0].set_title(f"Stock Price of {ticker}")
axs[0].set_ylabel("Price")
axs[0].legend(loc="upper right")

# Plot RSI
axs[1].plot(df.index, df['rsi'], label="RSI", color='purple', linewidth=2)
axs[1].axhline(80, linestyle='dashed', color='red', alpha=0.7)
axs[1].axhline(20, linestyle='dashed', color='green', alpha=0.7)
axs[1].set_title("Relative Strength Index (RSI)")
axs[1].set_ylabel("RSI")
axs[1].set_ylim([0,100])
axs[1].legend(loc="upper right")

# Plot MACD
axs[2].plot(df.index, df['macd'], label="MACD", color='black', linewidth=2)
axs[2].bar(df.index, df['macd'], 
           color=['green' if v >= 0 else 'red' for v in df['macd']], 
           alpha=0.5)
axs[2].axhline(0, color='black', alpha=0.5)
axs[2].set_title("Moving Average Convergence Divergence (MACD)")
axs[2].set_ylabel("MACD")
axs[2].legend(loc="upper right")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Plot Normalized Features

# %%
fig, axs = plt.subplots(3, figsize=(12, 10), gridspec_kw={'height_ratios': [3, 1, 1]})

# Plot stock price with volume
axs[0].bar(norm_df.index, norm_df['volume'], label=f"Volume", color='grey', alpha=0.3)
axs[0].plot(norm_df.index, norm_df['close'], label="Close Price", color='black', linewidth=2)
axs[0].plot(norm_df.index, norm_df['sma'], label="Simple moving average", color='cyan', alpha=0.5)
axs[0].plot(norm_df.index, norm_df['ema'], label="Exponential moving average", color='magenta', alpha=0.5)
axs[0].set_title(f"Normalized Stock Price of {ticker}")
axs[0].set_ylabel("Normalized Price")
axs[0].legend(loc="upper right")

# Plot RSI
axs[1].plot(norm_df.index, norm_df['rsi'], label="RSI", color='purple', linewidth=2)
axs[1].axhline(0.2, linestyle='dashed', color='red', alpha=0.7)
axs[1].axhline(0.8, linestyle='dashed', color='green', alpha=0.7)
axs[1].set_title("Relative Strength Index (RSI)")
axs[1].set_ylabel("Normalized RSI")
axs[1].legend(loc="upper right")

# Plot MACD
axs[2].plot(norm_df.index, 2*(norm_df['macd']-0.5), label="MACD *displayed [-1,1]", color='black', linewidth=2)
axs[2].bar(norm_df.index, 2*(norm_df['macd']-0.5), 
           color=['green' if v >= 0 else 'red' for v in 2*(norm_df['macd']-0.5)], 
           alpha=0.5)
axs[2].axhline(0, color='black', alpha=0.5)
axs[2].set_title("Moving Average Convergence Divergence (MACD)")
axs[2].set_ylabel("Normalized MACD")
axs[2].legend(loc="upper right")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Calculate target value

# %%
norm_df['target'] = calculate_closing_diff(norm_df)
norm_df
# Out:
#          open      high       low     close    volume       rdr       sma  \
# 0    0.253886  0.184133  0.194596  0.000000  0.171469  0.469399  0.836295
# 1    0.031086  0.000000  0.120188  0.058511  0.173057  0.246865  0.814693
# 2    0.000000  0.000000  0.003452  0.000000  0.306118  0.402166  0.780642
# 3    0.000000  0.000000  0.000000  0.000000  0.251370  0.197753  0.744560
# 4    0.028368  0.044536  0.000000  0.064407  0.282035  0.328413  0.690125
# ..        ...       ...       ...       ...       ...       ...       ...
# 198  0.268890  0.220030  0.177711  0.130913  0.460763  0.492524  0.575938
# 199  0.000000  0.209429  0.114709  0.148300  0.341349  0.624178  0.422977
# 200  0.301481  0.327847  0.295432  0.327586  0.433537  0.459925  0.245138
# 201  0.308557  0.344089  0.296938  0.452908  0.283043  0.476851  0.064204
# 202  0.299781  0.202592  0.001004  0.000000  0.790656  0.880588  0.017210
#
#           ema       rsi      macd    target
# 0    0.874582  0.056990  0.091122  0.000000
# 1    0.832022  0.000000  0.097195  0.058511
# 2    0.736376  0.000000  0.055355 -0.058511
# 3    0.616433  0.045706  0.037074  0.000000
# 4    0.459921  0.072020  0.064626  0.064407
# ..        ...       ...       ...       ...
# 198  0.824818  0.670916  0.458126 -0.339044
# 199  0.648564  0.638954  0.312073  0.017387
# 200  0.560669  0.618639  0.304625  0.179286
# 201  0.536218  0.611746  0.365305  0.125321
# 202  0.350900  0.342749  0.227829 -0.452908
#
# [203 rows x 11 columns]

# %% [markdown]
# ### Split train & test sets

# %%
current_day = -1 #predict closing delta
prev_days = 20
data = norm_df.to_numpy()
data_x, data_y = generate_model_data(data, sequence_size=prev_days, target_idx=current_day)
print('Model Data')
print("------------------------------------")
print("> Data X: " + str(data_x.shape))
print("> Data y: " + str(data_y.shape))
print()

test_size = 30
data_x_train = data_x[:-test_size]
data_y_train = data_y[:-test_size]
print('Train Set')
print("------------------------------------")
print("> Data X: " + str(data_x_train.shape))
print("> Data y: " + str(data_y_train.shape))
print()


data_x_test = data_x[-test_size:]
data_y_test = data_y[-test_size:]
print('Test Set')
print("------------------------------------")
print("> Data X: " + str(data_x_test.shape))
print("> Data y: " + str(data_y_test.shape))
# Out:
# Model Data
# ------------------------------------
# > Data X: (182, 20, 11)
# > Data y: (182, 1)
#
# Train Set
# ------------------------------------
# > Data X: (152, 20, 11)
# > Data y: (152, 1)
#
# Test Set
# ------------------------------------
# > Data X: (30, 20, 11)
# > Data y: (30, 1)

# %% [markdown]
# ### Define Model

# %%
class TransformerModel(tf.keras.Model):
    def __init__(self, num_layers, hidden_dim, output_size, num_heads=4, dropout_rate=0.1):
        super(TransformerModel, self).__init__()

        self.num_layers = num_layers
        self.hidden_dim = hidden_dim
        self.output_size = output_size
        self.num_heads = num_heads

        # Transformer Encoder Layers
        self.encoder_layers = [
            tf.keras.layers.MultiHeadAttention(num_heads=num_heads, key_dim=hidden_dim) 
            for _ in range(num_layers)
        ]

        self.norm_layers = [
            tf.keras.layers.LayerNormalization(epsilon=1e-6) 
            for _ in range(num_layers)
        ]

        self.dropout_layers = [
            tf.keras.layers.Dropout(dropout_rate) 
            for _ in range(num_layers)
        ]

        # Fully Connected Layers for Prediction
        self.global_avg_pool = tf.keras.layers.GlobalAveragePooling1D()
        self.dense1 = tf.keras.layers.Dense(hidden_dim // 2, activation="relu")
        self.dense2 = tf.keras.layers.Dense(output_size)

    def call(self, x):
        # Apply Transformer Encoder Layers
        for i in range(self.num_layers):
            attn_output = self.encoder_layers[i](x, x)  # Self-attention
            x = self.norm_layers[i](x + attn_output)  # Add & Normalize
            x = self.dropout_layers[i](x)

        # Reduce sequence dimension using Global Average Pooling
        x = self.global_avg_pool(x)

        # Fully Connected Layers
        x = self.dense1(x)
        x = self.dense2(x)
        
        return x

# %% [markdown]
# ### Train Model

# %%
num_layers = 3
hidden_dim = 64
output_size = 1  # Predicting next-day stock price
num_heads = 4
dropout_rate = 0.1

model = TransformerModel(num_layers, hidden_dim, output_size, num_heads, dropout_rate)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss="mse",
    metrics=["mae"]
)

history = model.fit(
    x = data_x_train,
    y = data_y_train,
    epochs=50,
    batch_size=32,
    validation_data=(data_x_test, data_y_test)
)
# Out:
# Epoch 1/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 264ms/step - loss: 0.0956 - mae: 0.2535 - val_loss: 0.0530 - val_mae: 0.1749
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 188ms/step - loss: 0.0537 - mae: 0.1858 - val_loss: 0.0930 - val_mae: 0.2774
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 0.0463 - mae: 0.1802 - val_loss: 0.0409 - val_mae: 0.1545
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - loss: 0.0226 - mae: 0.1208 - val_loss: 0.0311 - val_mae: 0.1356
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.0197 - mae: 0.1143 - val_loss: 0.0273 - val_mae: 0.1248
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 0.0185 - mae: 0.1103 - val_loss: 0.0276 - val_mae: 0.1209
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.0164 - mae: 0.0982 - val_loss: 0.0246 - val_mae: 0.1203
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 0.0159 - mae: 0.0992 - val_loss: 0.0243 - val_mae: 0.1154
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - loss: 0.0156 - mae: 0.0977 - val_loss: 0.0253 - val_mae: 0.1148
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - loss: 0.0156 - mae: 0.0970 - val_loss: 0.0238 - val_mae: 0.1156
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.0149 - mae: 0.0952 - val_loss: 0.0249 - val_mae: 0.1169
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - loss: 0.0147 - mae: 0.0928 - val_loss: 0.0248 - val_mae: 0.1192
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.0146 - mae: 0.0945 - val_loss: 0.0250 - val_mae: 0.1183
# Epoch 14/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 0.0145 - mae: 0.0932 - val_loss: 0.0244 - val_mae: 0.1173
# Epoch 15/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - loss: 0.0143 - mae: 0.0925 - val_loss: 0.0242 - val_mae: 0.1173
# Epoch 16/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step - loss: 0.0141 - mae: 0.0919 - val_loss: 0.0242 - val_mae: 0.1169
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 0.0141 - mae: 0.0919 - val_loss: 0.0242 - val_mae: 0.1164
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 0.0140 - mae: 0.0917 - val_loss: 0.0242 - val_mae: 0.1165
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - loss: 0.0140 - mae: 0.0911 - val_loss: 0.0242 - val_mae: 0.1166
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 0.0139 - mae: 0.0910 - val_loss: 0.0243 - val_mae: 0.1170
# Epoch 21/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 138ms/step - loss: 0.0141 - mae: 0.0917 - val_loss: 0.0243 - val_mae: 0.1169
# Epoch 22/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - loss: 0.0140 - mae: 0.0914 - val_loss: 0.0243 - val_mae: 0.1167
# Epoch 23/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 0.0139 - mae: 0.0909 - val_loss: 0.0244 - val_mae: 0.1167
# Epoch 24/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 0.0140 - mae: 0.0913 - val_loss: 0.0243 - val_mae: 0.1167
# Epoch 25/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0140 - mae: 0.0912 - val_loss: 0.0242 - val_mae: 0.1165
# Epoch 26/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 0.0139 - mae: 0.0910 - val_loss: 0.0241 - val_mae: 0.1166
# Epoch 27/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0139 - mae: 0.0909 - val_loss: 0.0241 - val_mae: 0.1163
# Epoch 28/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0140 - mae: 0.0912 - val_loss: 0.0241 - val_mae: 0.1166
# Epoch 29/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.0140 - mae: 0.0912 - val_loss: 0.0242 - val_mae: 0.1163
# Epoch 30/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 0.0139 - mae: 0.0908 - val_loss: 0.0241 - val_mae: 0.1167
# Epoch 31/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.0140 - mae: 0.0913 - val_loss: 0.0241 - val_mae: 0.1167
# Epoch 32/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - loss: 0.0140 - mae: 0.0910 - val_loss: 0.0242 - val_mae: 0.1162
# Epoch 33/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 0.0140 - mae: 0.0909 - val_loss: 0.0240 - val_mae: 0.1166
# Epoch 34/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 0.0140 - mae: 0.0916 - val_loss: 0.0241 - val_mae: 0.1168
# Epoch 35/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0139 - mae: 0.0906 - val_loss: 0.0242 - val_mae: 0.1166
# Epoch 36/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0140 - mae: 0.0910 - val_loss: 0.0242 - val_mae: 0.1171
# Epoch 37/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0140 - mae: 0.0913 - val_loss: 0.0242 - val_mae: 0.1171
# Epoch 38/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0139 - mae: 0.0909 - val_loss: 0.0242 - val_mae: 0.1170
# Epoch 39/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0139 - mae: 0.0909 - val_loss: 0.0243 - val_mae: 0.1172
# Epoch 40/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0140 - mae: 0.0911 - val_loss: 0.0243 - val_mae: 0.1169
# Epoch 41/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0139 - mae: 0.0909 - val_loss: 0.0242 - val_mae: 0.1173
# Epoch 42/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0139 - mae: 0.0911 - val_loss: 0.0242 - val_mae: 0.1170
# Epoch 43/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0140 - mae: 0.0912 - val_loss: 0.0243 - val_mae: 0.1172
# Epoch 44/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - loss: 0.0139 - mae: 0.0908 - val_loss: 0.0243 - val_mae: 0.1172
# Epoch 45/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - loss: 0.0139 - mae: 0.0909 - val_loss: 0.0243 - val_mae: 0.1171
# Epoch 46/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.0139 - mae: 0.0911 - val_loss: 0.0243 - val_mae: 0.1170
# Epoch 47/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - loss: 0.0139 - mae: 0.0908 - val_loss: 0.0243 - val_mae: 0.1173
# Epoch 48/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.0140 - mae: 0.0915 - val_loss: 0.0243 - val_mae: 0.1171
# Epoch 49/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0139 - mae: 0.0909 - val_loss: 0.0244 - val_mae: 0.1173
# Epoch 50/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0139 - mae: 0.0907 - val_loss: 0.0242 - val_mae: 0.1173

# %% [markdown]
# ### Plot Performance

# %%
plt.figure(figsize=(18, 6))

plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")

plt.title("Transformer Model Performance")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
train_predictions = model.predict(data_x_train)
train_actual = data_y_train
plt.plot(train_predictions, label='Training Prediction')
plt.plot(train_actual, label='Training Actual')
plt.xlabel('Days')
plt.ylabel('Normalized Stock Closing Delta')
plt.legend()
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x16d2cafc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step

# %%
diff = np.sign(train_predictions.flatten())-np.sign(train_actual.flatten())
thresh = np.max(np.abs(train_predictions))/2
significant = np.where(np.abs(train_predictions.flatten()) > thresh)
print('We perform predictions for ' + str(len(diff)) + ' days')
print('Let a significant day be a day where the absolute value of the predicted closing delta is greater than ' + str(thresh))
print('There are ' + str(len(significant[0])) + ' such events')
print('Of those events, we predict ' + str(np.count_nonzero(diff[significant])) + ' incorrectly')
# Out:
# We perform predictions for 152 days
# Let a significant day be a day where the absolute value of the predicted closing delta is greater than 0.04979733
# There are 22 such events
# Of those events, we predict 5 incorrectly

# %%
stock_price_train_pred = np.cumsum(train_predictions)
stock_price_train_actual = np.cumsum(train_actual)
plt.plot(stock_price_train_pred, label='Training Predicted')
plt.plot(stock_price_train_actual, label='Training Actual')
plt.title('Stock Prices via Accumulated Closing Deltas')
plt.xlabel('Days')
plt.ylabel('Stock Price')
plt.legend()

# %%
diff2 = stock_price_train_pred - stock_price_train_actual
plt.plot(diff2)

# %% [markdown]
# ### Test Model

# %%
test_predictions = model.predict(data_x_test)
test_actual = data_y_test
plt.plot(test_predictions, label='Testing Prediction')
plt.plot(test_actual, label='Testing Actual')
plt.xlabel('Days')
plt.ylabel('Normalized Stock Closing Delta')
plt.title("Predicted Normalized Closing Price Difference")
plt.legend()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step

# %%
stock_price_test_pred = np.cumsum(test_predictions)
stock_price_test_actual = np.cumsum(test_actual)
plt.plot(stock_price_test_pred, label='Testing Predicted')
plt.plot(stock_price_test_actual, label='Testing Actual')
plt.title('Stock Prices via Accumulated Closing Deltas')
plt.xlabel('Days')
plt.ylabel('Stock Price')
plt.legend()
